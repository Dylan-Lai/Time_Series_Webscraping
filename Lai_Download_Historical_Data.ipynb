# %%
import yfinance as yf
import matplotlib.pyplot as plt
import datetime

# %%
# Create Ticker variables
data = yf.Ticker("DIS")
#Set the time range
hist_data = data.history(start=datetime.datetime(2010, 1, 1),end=datetime.datetime.today())
hist_data.insert(0,"Date",hist_data.index)
hist_data.head(20)
# Out:
#                                                Date       Open       High  \
# Date
# 2010-01-04 00:00:00-05:00 2010-01-04 00:00:00-05:00  27.963019  28.178119
# 2010-01-05 00:00:00-05:00 2010-01-05 00:00:00-05:00  27.593046  27.670482
# 2010-01-06 00:00:00-05:00 2010-01-06 00:00:00-05:00  27.446781  27.532821
# 2010-01-07 00:00:00-05:00 2010-01-07 00:00:00-05:00  27.334927  27.412364
# 2010-01-08 00:00:00-05:00 2010-01-08 00:00:00-05:00  27.240285  27.481198
# 2010-01-11 00:00:00-05:00 2010-01-11 00:00:00-05:00  27.128433  27.309116
# 2010-01-12 00:00:00-05:00 2010-01-12 00:00:00-05:00  26.689625  26.775665
# 2010-01-13 00:00:00-05:00 2010-01-13 00:00:00-05:00  26.577773  26.990766
# 2010-01-14 00:00:00-05:00 2010-01-14 00:00:00-05:00  26.784270  26.827291
# 2010-01-15 00:00:00-05:00 2010-01-15 00:00:00-05:00  26.681026  26.801482
# 2010-01-19 00:00:00-05:00 2010-01-19 00:00:00-05:00  26.319656  26.835897
# 2010-01-20 00:00:00-05:00 2010-01-20 00:00:00-05:00  26.672419  26.878915
# ...

# %%
#Visualization of the Closing price
plt.figure(figsize=(16,8))
plt.title("Closing Price History")
plt.plot(hist_data["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Closing Price USD $", fontsize=18)
plt.show()

# %%
hist_data.to_csv('Lai_Historical_Data.csv', index=True)
